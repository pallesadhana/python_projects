# %% [markdown]
# 1. Import required libraries and read the dataset.

# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt 
data=pd.read_csv('honeyproduction.csv')
data
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# ...

# %% [markdown]
# 2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
data.head(5)
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %%
data.shape
# Out:
# (626, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.3+ KB

# %%
data.describe()
# Out:
#               numcol  yieldpercol     totalprod        stocks  priceperlb  \
# count     626.000000   626.000000  6.260000e+02  6.260000e+02  626.000000
# mean    60284.345048    62.009585  4.169086e+06  1.318859e+06    1.409569
# std     91077.087231    19.458754  6.883847e+06  2.272964e+06    0.638599
# min      2000.000000    19.000000  8.400000e+04  8.000000e+03    0.490000
# 25%      9000.000000    48.000000  4.750000e+05  1.430000e+05    0.932500
# 50%     26000.000000    60.000000  1.533000e+06  4.395000e+05    1.360000
# 75%     63750.000000    74.000000  4.175250e+06  1.489500e+06    1.680000
# max    510000.000000   136.000000  4.641000e+07  1.380000e+07    4.150000
#
#           prodvalue         year
# count  6.260000e+02   626.000000
# mean   4.715741e+06  2004.864217
# std    7.976110e+06     4.317306
# min    1.620000e+05  1998.000000
# 25%    7.592500e+05  2001.000000
# 50%    1.841500e+06  2005.000000
# 75%    4.703250e+06  2009.000000
# ...

# %%
data.tail(5)
# Out:
#     state   numcol  yieldpercol  totalprod     stocks  priceperlb  prodvalue  \
# 621    VA   4000.0           41   164000.0    23000.0        3.77   618000.0
# 622    WA  62000.0           41  2542000.0  1017000.0        2.38  6050000.0
# 623    WV   6000.0           48   288000.0    95000.0        2.91   838000.0
# 624    WI  60000.0           69  4140000.0  1863000.0        2.05  8487000.0
# 625    WY  50000.0           51  2550000.0   459000.0        1.87  4769000.0
#
#      year
# 621  2012
# 622  2012
# 623  2012
# 624  2012
# 625  2012

# %% [markdown]
# 3. Display the percentage distribution of the data in each year using the pie chart.

# %%
year_predict=data.groupby('year').size()/len(data)*100
#plot the pie chart 
plt.figure(figsize=(6,6))
plt.pie(year_predict,labels=year_counts.index,autopct='%1.1f%%')
plt.title('percentage Distribution of Data by year')
plt.axis('equal')
plt.show()

# %% [markdown]
# 4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
data['priceperlb']
# Out:
# 0      0.72
# 1      0.64
# 2      0.59
# 3      0.62
# 4      0.70
#        ...
# 621    3.77
# 622    2.38
# 623    2.91
# 624    2.05
# 625    1.87
# Name: priceperlb, Length: 626, dtype: float64

# %%
plt.figure(figsize=(10,6))
sns.distplot(data['priceperlb'])
plt.title('Distribution of price per lb')
plt.xlabel('price per lb')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15896\3078808183.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['priceperlb'])

# %%
Its a right skewed distribution or postive skew distribution the majority of the data is located on the left side of the graph 
and the mean or average is greater than the median

# %% [markdown]
# 5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and
# write your findings.

# %%
plt.figure(figsize=(8,6))
plt.scatter(data['numcol'],data['prodvalue'],alpha=0.5)
plt.title('relationship between the  numcol and prodval')
plt.xlabel('numcol')
plt.ylabel('prodvalue ')
plt.show()

# %% [markdown]
# Number of honey producing colonies.
# Value of production (total prod x priceperlb).
# Number of honey producing colonies.are more in the range of 100000 to 200000  the frequency is less in the 500000

# %% [markdown]
# 6. Plot and understand the relationship between categorical variable 'year' and a numerical variable
# 'prodvalue' through boxplot, and write your findings.

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='year',y='prodvalue',data=data)
plt.title('Boxplot of prob across different years')
plt.xlabel('year')
plt.ylabel('prodvalue')
plt.show()

# %%
Box plot which the x-axis show the year and prodvalue as y-axis 2010 having the more outliers

# %% [markdown]
# 7. Visualize and understand the relationship between the multiple pairs of variables throughout different years
# using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year')

# %%
sns.pairplot(data, vars=['numcol', 'yieldpercol', 'totalprod', 'prodvalue', 'year'], hue='year')
# Out:
# d:\Users\hp\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
pairplot are particularly uesful for visualizing the pairwise relationships between multiple numerical variables in data set

# %% [markdown]
# 8. Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol',
# 'total prod', 'stocks', 'price per lb', 'prodvalue')

# %%
data_subset = data[['numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb', 'prodvalue']]

#calculating correlation matrix
corr_matrix = data_subset.corr()

#plotting the heatmap
sns.heatmap(corr_matrix, annot=True)
plt.title("Correlation Matrix")
plt.show()

# %%
The heat map we can see that  totalproduct and numnumcol have the good correlation of the variable of 0.95 and priceperlb vs product value 
have negative correlation with -0.09
